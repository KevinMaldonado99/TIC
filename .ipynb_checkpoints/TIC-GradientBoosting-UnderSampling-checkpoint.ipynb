# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.preprocessing import OneHotEncoder
import re
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# ### Importar el dataset

# %%
data = pd.read_csv('./Data.csv')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19680\2202040361.py:1: DtypeWarning: Columns (30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('./Data.csv')

# %% [markdown]
# ### Informacion de la data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17087 entries, 0 to 17086
# Data columns (total 77 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   md5                         17087 non-null  object
#  1   sha1                        17087 non-null  object
#  2   file_extension              17087 non-null  object
#  3   EntryPoint                  17087 non-null  object
#  4   PEType                      17087 non-null  object
#  5   MachineType                 17087 non-null  object
#  6   magic_number                17087 non-null  object
#  7   bytes_on_last_page          17087 non-null  object
#  8   pages_in_file               17087 non-null  object
#  9   relocations                 17087 non-null  object
#  10  size_of_header              17087 non-null  object
#  11  min_extra_paragraphs        17087 non-null  object
#  12  max_extra_paragraphs        17087 non-null  object
#  13  init_ss_value               17087 non-null  object
#  14  init_sp_value               17087 non-null  object
#  15  init_ip_value               17087 non-null  object
#  16  init_cs_value               17087 non-null  object
#  17  over_lay_number             17087 non-null  object
#  18  oem_identifier              17087 non-null  object
#  19  address_of_ne_header        17087 non-null  object
#  20  Magic                       17087 non-null  object
#  21  SizeOfCode                  17087 non-null  object
#  22  SizeOfInitializedData       17087 non-null  object
#  23  SizeOfUninitializedData     17087 non-null  object
#  24  AddressOfEntryPoint         17087 non-null  object
#  25  BaseOfCode                  17087 non-null  object
#  26  BaseOfData                  17087 non-null  object
#  27  ImageBase                   17087 non-null  object
#  28  SectionAlignment            17087 non-null  object
#  29  FileAlignment               17087 non-null  object
#  30  OperatingSystemVersion      17087 non-null  object
#  31  ImageVersion                17087 non-null  object
#  32  SizeOfImage                 17087 non-null  object
#  33  SizeOfHeaders               17087 non-null  object
#  34  Checksum                    17087 non-null  object
#  35  Subsystem                   17087 non-null  object
#  36  DllCharacteristics          17087 non-null  object
#  37  SizeofStackReserve          17087 non-null  object
#  38  SizeofStackCommit           17087 non-null  object
#  39  SizeofHeapCommit            17087 non-null  object
#  40  SizeofHeapReserve           17087 non-null  object
#  41  LoaderFlags                 17087 non-null  object
#  42  text_VirtualSize            17087 non-null  object
#  43  text_VirtualAddress         17087 non-null  object
#  44  text_SizeOfRawData          17087 non-null  object
#  45  text_PointerToRawData       17087 non-null  object
#  46  text_PointerToRelocations   17087 non-null  object
#  47  text_PointerToLineNumbers   17087 non-null  object
#  48  text_Characteristics        17087 non-null  object
#  49  rdata_VirtualSize           17087 non-null  object
#  50  rdata_VirtualAddress        17087 non-null  object
#  51  rdata_SizeOfRawData         17087 non-null  object
#  52  rdata_PointerToRawData      17087 non-null  object
#  53  rdata_PointerToRelocations  17087 non-null  object
#  54  rdata_PointerToLineNumbers  17087 non-null  object
#  55  rdata_Characteristics       17087 non-null  object
#  56  registry_read               17087 non-null  float64
#  57  registry_write              17087 non-null  float64
#  58  registry_delete             17087 non-null  float64
#  59  registry_total              17087 non-null  float64
#  60  network_threats             17087 non-null  float64
#  61  network_dns                 17087 non-null  float64
#  62  network_http                17087 non-null  float64
#  63  network_connections         17087 non-null  float64
#  64  processes_malicious         17087 non-null  float64
#  65  processes_suspicious        17087 non-null  float64
#  66  processes_monitored         17087 non-null  float64
#  67  total_procsses              17087 non-null  float64
#  68  files_malicious             17087 non-null  float64
#  69  files_suspicious            17087 non-null  float64
#  70  files_text                  17087 non-null  float64
#  71  files_unknown               17087 non-null  float64
#  72  dlls_calls                  17087 non-null  float64
#  73  apis                        17087 non-null  float64
#  74  Class                       17087 non-null  object
#  75  Category                    17087 non-null  object
#  76  Family                      17087 non-null  object
# dtypes: float64(18), object(59)
# memory usage: 10.0+ MB

# %% [markdown]
# ### Numero de columnas y filas

# %%
print("Shape", data.shape)
print("Filas", data.shape[0])
print("Columnas", data.shape[1])
# Out:
# Shape (17087, 77)
# Filas 17087
# Columnas 77

# %% [markdown]
# ### Listar todas las columnas por tipo de varibale: categorica y numerica

# %%
# --- Detectar columnas categóricas ---
cat_cols = data.select_dtypes(include=["object"]).columns.tolist()

print("Columnas categóricas:")
print(cat_cols)
# Out:
# Columnas categóricas:
# ['md5', 'sha1', 'file_extension', 'EntryPoint', 'PEType', 'MachineType', 'magic_number', 'bytes_on_last_page', 'pages_in_file', 'relocations', 'size_of_header', 'min_extra_paragraphs', 'max_extra_paragraphs', 'init_ss_value', 'init_sp_value', 'init_ip_value', 'init_cs_value', 'over_lay_number', 'oem_identifier', 'address_of_ne_header', 'Magic', 'SizeOfCode', 'SizeOfInitializedData', 'SizeOfUninitializedData', 'AddressOfEntryPoint', 'BaseOfCode', 'BaseOfData', 'ImageBase', 'SectionAlignment', 'FileAlignment', 'OperatingSystemVersion', 'ImageVersion', 'SizeOfImage', 'SizeOfHeaders', 'Checksum', 'Subsystem', 'DllCharacteristics', 'SizeofStackReserve', 'SizeofStackCommit', 'SizeofHeapCommit', 'SizeofHeapReserve', 'LoaderFlags', 'text_VirtualSize', 'text_VirtualAddress', 'text_SizeOfRawData', 'text_PointerToRawData', 'text_PointerToRelocations', 'text_PointerToLineNumbers', 'text_Characteristics', 'rdata_VirtualSize', 'rdata_VirtualAddress', 'rdata_SizeOfRawData', 'rdata_PointerToRawData', 'rdata_PointerToRelocations', 'rdata_PointerToLineNumbers', 'rdata_Characteristics', 'Class', 'Category', 'Family']

# %%
# --- Detectar columnas numericas ---
num_cols = data.select_dtypes(include=["float64"]).columns.tolist()

print("Columnas numericas detectadas:")
print(num_cols )
# Out:
# Columnas numericas detectadas:
# ['registry_read', 'registry_write', 'registry_delete', 'registry_total', 'network_threats', 'network_dns', 'network_http', 'network_connections', 'processes_malicious', 'processes_suspicious', 'processes_monitored', 'total_procsses', 'files_malicious', 'files_suspicious', 'files_text', 'files_unknown', 'dlls_calls', 'apis']

# %% [markdown]
# ### Cantidad de  variables numericas y categoricas

# %%
data.dtypes.value_counts()
# Out:
# object     59
# float64    18
# Name: count, dtype: int64

# %% [markdown]
# ### Revisar la cardinalidad de las variables categoricas
# Para ver si se aplica one-hot Encoder o Label Enconder
# One-hot Se aplica a variables que tenga pocas categorias
# Label Encoder
# Ventajas no crea varias columnas Útil para modelos que no interpretan los números como un orden (ej. árboles: Decision Tree, Random Forest, XGBoost, LightGBM).
# Todas esas variables estan categorizadas como object, en las cuales algunas eran object y otras eran hexcd que estans como object

# %%
# --- Revisar cardinalidad (número de valores únicos) ---
cat_cardinalidad = {c: data[c].nunique() for c in cat_cols}
print("\nCardinalidad de columnas categóricas:")
for col, nunique in cat_cardinalidad.items():
    print(f"{col}: {nunique}")
# Out:
# Cardinalidad de columnas categóricas:
# md5: 9855
# sha1: 9856
# file_extension: 1
# EntryPoint: 6191
# PEType: 3
# MachineType: 3
# magic_number: 2
# bytes_on_last_page: 64
# pages_in_file: 63
# relocations: 43
# size_of_header: 43
# min_extra_paragraphs: 42
# max_extra_paragraphs: 40
# init_ss_value: 40
# init_sp_value: 46
# init_ip_value: 52
# init_cs_value: 52
# over_lay_number: 49
# oem_identifier: 47
# address_of_ne_header: 69
# Magic: 3
# SizeOfCode: 2488
# SizeOfInitializedData: 2204
# SizeOfUninitializedData: 404
# AddressOfEntryPoint: 5908
# BaseOfCode: 336
# BaseOfData: 942
# ImageBase: 99
# SectionAlignment: 9
# FileAlignment: 8
# OperatingSystemVersion: 27
# ImageVersion: 116
# SizeOfImage: 1997
# SizeOfHeaders: 24
# Checksum: 3621
# Subsystem: 5
# DllCharacteristics: 57
# SizeofStackReserve: 57
# SizeofStackCommit: 42
# SizeofHeapCommit: 10
# SizeofHeapReserve: 22
# LoaderFlags: 4
# text_VirtualSize: 5553
# text_VirtualAddress: 121
# text_SizeOfRawData: 2143
# text_PointerToRawData: 124
# text_PointerToRelocations: 6
# text_PointerToLineNumbers: 12
# text_Characteristics: 40
# rdata_VirtualSize: 3243
# rdata_VirtualAddress: 747
# rdata_SizeOfRawData: 968
# rdata_PointerToRawData: 1556
# rdata_PointerToRelocations: 4
# rdata_PointerToLineNumbers: 4
# rdata_Characteristics: 37
# Class: 2
# Category: 3
# Family: 17

# %% [markdown]
# ### Ver los valores nulos

# %%
print("\n Conteo de valores nulos por columna:")
print(data.isnull().sum())
# Out:
#  Conteo de valores nulos por columna:
# md5               0
# sha1              0
# file_extension    0
# EntryPoint        0
# PEType            0
#                  ..
# dlls_calls        0
# apis              0
# Class             0
# Category          0
# Family            0
# Length: 77, dtype: int64

# %% [markdown]
# ### Valores vacios por columna

# %%
# 4) Detectar valores vacíos (celdas con string vacío o solo espacios)
print("\n Conteo de valores vacíos por columna:")
print((data.applymap(lambda x: str(x).strip() == '')).sum())
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19680\2919232096.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   print((data.applymap(lambda x: str(x).strip() == '')).sum())
#  Conteo de valores vacíos por columna:
# md5               0
# sha1              0
# file_extension    0
# EntryPoint        0
# PEType            0
#                  ..
# dlls_calls        0
# apis              0
# Class             0
# Category          0
# Family            0
# Length: 77, dtype: int64

# %% [markdown]
# ### Ver  filas vacias

# %%
# 5) Detectar filas completamente vacías
print("\n Número de filas completamente vacías:")
print(data.isnull().all(axis=1).sum())
# Out:
#  Número de filas completamente vacías:
# 0

# %%
# 6) Ver filas sospechosas (con valores nulos o vacíos en alguna columna)
print("\n Filas con valores nulos o vacíos:")
print(data[data.isnull().any(axis=1) | data.applymap(lambda x: str(x).strip() == '').any(axis=1)])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19680\3230463956.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   print(data[data.isnull().any(axis=1) | data.applymap(lambda x: str(x).strip() == '').any(axis=1)])
#  Filas con valores nulos o vacíos:
# Empty DataFrame
# Columns: [md5, sha1, file_extension, EntryPoint, PEType, MachineType, magic_number, bytes_on_last_page, pages_in_file, relocations, size_of_header, min_extra_paragraphs, max_extra_paragraphs, init_ss_value, init_sp_value, init_ip_value, init_cs_value, over_lay_number, oem_identifier, address_of_ne_header, Magic, SizeOfCode, SizeOfInitializedData, SizeOfUninitializedData, AddressOfEntryPoint, BaseOfCode, BaseOfData, ImageBase, SectionAlignment, FileAlignment, OperatingSystemVersion, ImageVersion, SizeOfImage, SizeOfHeaders, Checksum, Subsystem, DllCharacteristics, SizeofStackReserve, SizeofStackCommit, SizeofHeapCommit, SizeofHeapReserve, LoaderFlags, text_VirtualSize, text_VirtualAddress, text_SizeOfRawData, text_PointerToRawData, text_PointerToRelocations, text_PointerToLineNumbers, text_Characteristics, rdata_VirtualSize, rdata_VirtualAddress, rdata_SizeOfRawData, rdata_PointerToRawData, rdata_PointerToRelocations, rdata_PointerToLineNumbers, rdata_Characteristics, registry_read, registry_write, registry_delete, registry_total, network_threats, network_dns, network_http, network_connections, processes_malicious, processes_suspicious, processes_monitored, total_procsses, files_malicious, files_suspicious, files_text, files_unknown, dlls_calls, apis, Class, Category, Family]
# Index: []
#
# [0 rows x 77 columns]

# %% [markdown]
# ### Distribucion multiclase Bening, Ransoware y Trojan
# Esta desbalanceada la clase

# %%
# Contar muestras por categoría
class_counts = data["Category"].value_counts()

# Imprimir valores exactos
print("Distribución de clases:\n", class_counts)

# Graficar
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
class_counts.plot(kind="bar", color=["skyblue", "salmon", "orange"])
plt.title("Distribución de Clases (Benign vs Ransomware vs Trojan)")
plt.xlabel("Clase")
plt.ylabel("Número de muestras")
plt.xticks(rotation=0)
plt.show()
# Out:
# Distribución de clases:
#  Category
# Benign        10876
# Ransomware     4762
# Trojan         1449
# Name: count, dtype: int64

# %% [markdown]
# ### Definir features (X)
# Ahora X contiene solo las características.

# %%
X = data.drop(columns=["Class", "Category", "Family"], errors="ignore")
print("Shape de X (features):", X.shape)
# Out:
# Shape de X (features): (17087, 74)

# %% [markdown]
# ### Definir target

# %%
y = data["Category"] # multiclase: Benign, Ransomware, Trojan
print("Shape de y (target):", y.shape)
# Out:
# Shape de y (target): (17087,)

# %% [markdown]
# ### Eliminacion de columnas que no aportan valor

# %%
# 3. Eliminar columnas que no aportan valor
# md5, sha1 identificador
# file_extension tipo de extension exe 
#  "text_PointerToRelocations", "text_PointerToLineNumbers", solo tiene 0
#   "rdata_PointerToRelocations", "rdata_PointerToLineNumbers", solo tiene 0
#magic number no aporta 
# No aporta magic debido a que solo tiene una categoria
#EntryPoint variable redundante con Addres of entrypoint
cols_drop = [
    "md5", "sha1","file_extension","network_threats", "Magic", "magic_number",
    "oem_identifier", "address_of_ne_header",
     "text_PointerToRelocations", "text_PointerToLineNumbers",
    "rdata_PointerToRelocations", "rdata_PointerToLineNumbers",
    "Class", "Category", "Family", "registry_total", "total_procsses", "OperatingSystemVersion", "ImageVersion",

    "files_malicious","files_suspicious"
   "files_text, files_unknown","processes_malicious","processes_suspicious","processes_monitored"]
X = X.drop(columns=cols_drop, errors="ignore")
print("Shape de X después de eliminar columnas no útiles:", X.shape)
# Out:
# Shape de X después de eliminar columnas no útiles: (17087, 54)

# %%
print("Shape del dataset limpio:", X.shape)
print("Columnas:", X.columns.tolist())
# Out:
# Shape del dataset limpio: (17087, 54)
# Columnas: ['EntryPoint', 'PEType', 'MachineType', 'bytes_on_last_page', 'pages_in_file', 'relocations', 'size_of_header', 'min_extra_paragraphs', 'max_extra_paragraphs', 'init_ss_value', 'init_sp_value', 'init_ip_value', 'init_cs_value', 'over_lay_number', 'SizeOfCode', 'SizeOfInitializedData', 'SizeOfUninitializedData', 'AddressOfEntryPoint', 'BaseOfCode', 'BaseOfData', 'ImageBase', 'SectionAlignment', 'FileAlignment', 'SizeOfImage', 'SizeOfHeaders', 'Checksum', 'Subsystem', 'DllCharacteristics', 'SizeofStackReserve', 'SizeofStackCommit', 'SizeofHeapCommit', 'SizeofHeapReserve', 'LoaderFlags', 'text_VirtualSize', 'text_VirtualAddress', 'text_SizeOfRawData', 'text_PointerToRawData', 'text_Characteristics', 'rdata_VirtualSize', 'rdata_VirtualAddress', 'rdata_SizeOfRawData', 'rdata_PointerToRawData', 'rdata_Characteristics', 'registry_read', 'registry_write', 'registry_delete', 'network_dns', 'network_http', 'network_connections', 'files_suspicious', 'files_text', 'files_unknown', 'dlls_calls', 'apis']

# %% [markdown]
# ### Renombrar variables

# %%
# Mapeo de nombres largos a cortos
rename_map = {
    "Intel 386 or later, and compatibles": "Intel386",
    "AMD AMD64": "AMD64",
    "MachineType": "Unknown"  # por si aparece un valor raro como 'MachineType'
}

# Aplicar reemplazo en la columna MachineType
if "MachineType" in X.columns:
    X["MachineType"] = X["MachineType"].replace(rename_map)

print("Valores únicos después del renombrado:")
print(X["MachineType"].unique())
# Out:
# Valores únicos después del renombrado:
# ['AMD64' 'Intel386' 'Unknown (0)']

# %%
# Conteo de nulos por columna
print(X.isnull().sum()[X.isnull().sum() > 0])
# Out:
# Series([], dtype: int64)

# %%
# Reemplazar '0' por IMAGE_SUBSYSTEM_UNKNOWN
if "Subsystem" in X.columns:
    X["Subsystem"] = X["Subsystem"].replace("0", "IMAGE_SUBSYSTEM_UNKNOWN")

print("Categorías únicas después:", X["Subsystem"].unique())
print("Conteo actualizado:")
print(X["Subsystem"].value_counts())
# Out:
# Categorías únicas después: ['IMAGE_SUBSYSTEM_WINDOWS_GUI' 'IMAGE_SUBSYSTEM_WINDOWS_CUI'
#  'IMAGE_SUBSYSTEM_NATIVE' 'IMAGE_SUBSYSTEM_UNKNOWN']
# Conteo actualizado:
# Subsystem
# IMAGE_SUBSYSTEM_WINDOWS_GUI    13169
# IMAGE_SUBSYSTEM_WINDOWS_CUI     3487
# IMAGE_SUBSYSTEM_UNKNOWN          341
# IMAGE_SUBSYSTEM_NATIVE            90
# Name: count, dtype: int64

# %% [markdown]
# ### Verificar las variables con error

# %%
# Ver todas las filas que tienen ese valor
X[X["PEType"] == "Unknown (0x2000)"]
# Out:
#      EntryPoint            PEType MachineType bytes_on_last_page  \
# 999      0x0000  Unknown (0x2000)    Intel386             0x0050
# 9655    0x2800a  Unknown (0x2000)    Intel386             0x0050
#
#      pages_in_file relocations size_of_header min_extra_paragraphs  \
# 999         0x0002      0x0000         0x0004               0x000F
# 9655        0x0002      0x0000         0x0004               0x0000
#
#      max_extra_paragraphs init_ss_value  ... registry_write registry_delete  \
# 999                0xFFFF        0x0000  ...            0.0             0.0
# 9655               0xFFFF        0x0000  ...            0.0             1.0
#
#      network_dns network_http network_connections files_suspicious files_text  \
# 999          0.0          0.0                 4.0              0.0        2.0
# 9655         0.0          0.0                12.0              0.0        0.0
#
#      files_unknown dlls_calls   apis
# 999            0.0        0.0    0.0
# 9655           0.0        0.0  338.0
#
# [2 rows x 54 columns]

# %% [markdown]
# ### Eliminar filas que tienen errores

# %%
# === Eliminar filas con PEType = 'Unknown (0x2000)' ===
if "PEType" in X.columns:
    filas_iniciales = X.shape[0]
    mask = X["PEType"] != "Unknown (0x2000)"
    X = X[mask]
    y = y[mask]   # eliminar también en y
    print(f"Filas eliminadas (PEType): {filas_iniciales - X.shape[0]}")
# Out:
# Filas eliminadas (PEType): 2

# %%
# === Eliminar filas con MachineType = 'Unknown (0)' ===
filas_iniciales = X.shape[0]
if "MachineType" in X.columns:
    mask = X["MachineType"] != "Unknown (0)"
    X = X[mask]
    y = y[mask]   # eliminar también en y

filas_finales = X.shape[0]

# %%
print(f"Filas eliminadas (MachineType): {filas_iniciales - filas_finales}")
print(f"Shape final de X: {X.shape}")
print(f"Shape final de y: {y.shape}")
print("Valores únicos en MachineType:", X["MachineType"].unique())
# Out:
# Filas eliminadas (MachineType): 6
# Shape final de X: (17079, 54)
# Shape final de y: (17079,)
# Valores únicos en MachineType: ['AMD64' 'Intel386']

# %% [markdown]
# ### Limpieza de la variable AddressOfEntryPoint

# %%
def limpiar_hex_con_texto(val):
    if isinstance(val, str):
        val = val.strip()
        if val == "0":       # caso especial: valor 0
            return 0.0
        match = re.search(r"0x[0-9A-Fa-f]+", val)
        if match:
            try:
                return float(int(match.group(0), 16))
            except:
                return np.nan
        return np.nan
    return val
if "AddressOfEntryPoint" in X.columns:
    X["AddressOfEntryPoint"] = (
        X["AddressOfEntryPoint"]
        .map(limpiar_hex_con_texto)
        .astype("float64")
    )
    print("Columna AddressOfEntryPoint corregida sin convertir los '0' a NaN.")
    print("Nulos restantes:", X["AddressOfEntryPoint"].isnull().sum())
# Out:
# Columna AddressOfEntryPoint corregida sin convertir los '0' a NaN.
# Nulos restantes: 0

# %%
# Conteo de nulos por columna
print(X.isnull().sum()[X.isnull().sum() > 0])
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### Convertir las variables  hexadecimales a float

# %%
import re
import numpy as np

# === 1) Define las categóricas que NO deben tocarse ===
CATEGORICAS_EXCLUIR = [
    "MachineType", "Subsystem", "PEType",
    "DllCharacteristics", "text_Characteristics", "rdata_Characteristics"
]
cat_presentes = [c for c in CATEGORICAS_EXCLUIR if c in X.columns]

# === 2) Funciones auxiliares ===
HEX_REGEX = re.compile(r"^\s*0[xX][0-9A-Fa-f]+\s*$")

def es_hex(s: str) -> bool:
    return isinstance(s, str) and bool(HEX_REGEX.match(s.strip()))

def parsear_num(val):
    """Convierte hex ('0x...') o decimal en texto a float64. Si falla -> NaN."""
    if isinstance(val, str):
        s = val.strip()
        if es_hex(s):
            try:
                return float(int(s, 16))
            except:
                return np.nan
        try:
            return float(s)
        except:
            return np.nan
    if val is None or (isinstance(val, float) and np.isnan(val)):
        return np.nan
    try:
        return float(val)
    except:
        return np.nan

# === 3) Detectar columnas 'object' con al menos un valor hexadecimal ===
hex_cols = []
for col in X.select_dtypes(include=["object"]).columns:
    if col in cat_presentes:
        continue  # excluye categóricas
    muestra = X[col].dropna().astype(str)
    if muestra.map(es_hex).any():
      hex_cols.append(col)
print("Columnas detectadas con valores hexadecimales:", hex_cols)

# === 4) Convertir SOLO esas columnas a float64 ===
for col in hex_cols:
    X[col] = X[col].map(parsear_num).astype("float64")

# (Opcional) Verificación
print(X[hex_cols].dtypes if hex_cols else "No se detectaron columnas hexadecimales.")

# === 5) Exportar a CSV ===
output_path = "dataset_valoresfloat3.csv"
X.to_csv(output_path, index=False, encoding="utf-8")
print(f"Archivo exportado a: {output_path}")
# Out:
# Columnas detectadas con valores hexadecimales: ['EntryPoint', 'bytes_on_last_page', 'pages_in_file', 'relocations', 'size_of_header', 'min_extra_paragraphs', 'max_extra_paragraphs', 'init_ss_value', 'init_sp_value', 'init_ip_value', 'init_cs_value', 'over_lay_number', 'SizeOfCode', 'SizeOfInitializedData', 'SizeOfUninitializedData', 'BaseOfCode', 'BaseOfData', 'ImageBase', 'SectionAlignment', 'FileAlignment', 'SizeOfImage', 'SizeOfHeaders', 'Checksum', 'SizeofStackReserve', 'SizeofStackCommit', 'SizeofHeapCommit', 'SizeofHeapReserve', 'LoaderFlags', 'text_VirtualSize', 'text_VirtualAddress', 'text_SizeOfRawData', 'text_PointerToRawData', 'rdata_VirtualSize', 'rdata_VirtualAddress', 'rdata_SizeOfRawData', 'rdata_PointerToRawData']
# EntryPoint                 float64
# bytes_on_last_page         float64
# pages_in_file              float64
# relocations                float64
# size_of_header             float64
# min_extra_paragraphs       float64
# max_extra_paragraphs       float64
# init_ss_value              float64
# init_sp_value              float64
# init_ip_value              float64
# init_cs_value              float64
# over_lay_number            float64
# SizeOfCode                 float64
# SizeOfInitializedData      float64
# SizeOfUninitializedData    float64
# BaseOfCode                 float64
# BaseOfData                 float64
# ImageBase                  float64
# SectionAlignment           float64
# FileAlignment              float64
# SizeOfImage                float64
# SizeOfHeaders              float64
# Checksum                   float64
# SizeofStackReserve         float64
# SizeofStackCommit          float64
# SizeofHeapCommit           float64
# SizeofHeapReserve          float64
# LoaderFlags                float64
# text_VirtualSize           float64
# text_VirtualAddress        float64
# text_SizeOfRawData         float64
# text_PointerToRawData      float64
# rdata_VirtualSize          float64
# rdata_VirtualAddress       float64
# rdata_SizeOfRawData        float64
# rdata_PointerToRawData     float64
# dtype: object
# Archivo exportado a: dataset_valoresfloat3.csv

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17079 entries, 0 to 17086
# Data columns (total 54 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EntryPoint               17079 non-null  float64
#  1   PEType                   17079 non-null  object
#  2   MachineType              17079 non-null  object
#  3   bytes_on_last_page       17079 non-null  float64
#  4   pages_in_file            17079 non-null  float64
#  5   relocations              17079 non-null  float64
#  6   size_of_header           17079 non-null  float64
#  7   min_extra_paragraphs     17079 non-null  float64
#  8   max_extra_paragraphs     17079 non-null  float64
#  9   init_ss_value            17079 non-null  float64
#  10  init_sp_value            17079 non-null  float64
#  11  init_ip_value            17079 non-null  float64
#  12  init_cs_value            17079 non-null  float64
#  13  over_lay_number          17079 non-null  float64
#  14  SizeOfCode               17079 non-null  float64
#  15  SizeOfInitializedData    17079 non-null  float64
#  16  SizeOfUninitializedData  17079 non-null  float64
#  17  AddressOfEntryPoint      17079 non-null  float64
#  18  BaseOfCode               17079 non-null  float64
#  19  BaseOfData               17079 non-null  float64
#  20  ImageBase                17079 non-null  float64
#  21  SectionAlignment         17079 non-null  float64
#  22  FileAlignment            17079 non-null  float64
#  23  SizeOfImage              17079 non-null  float64
#  24  SizeOfHeaders            17079 non-null  float64
#  25  Checksum                 17079 non-null  float64
#  26  Subsystem                17079 non-null  object
#  27  DllCharacteristics       17079 non-null  object
#  28  SizeofStackReserve       17079 non-null  float64
#  29  SizeofStackCommit        17079 non-null  float64
#  30  SizeofHeapCommit         17079 non-null  float64
#  31  SizeofHeapReserve        17079 non-null  float64
#  32  LoaderFlags              17079 non-null  float64
#  33  text_VirtualSize         17079 non-null  float64
#  34  text_VirtualAddress      17079 non-null  float64
#  35  text_SizeOfRawData       17079 non-null  float64
#  36  text_PointerToRawData    17079 non-null  float64
#  37  text_Characteristics     17079 non-null  object
#  38  rdata_VirtualSize        17079 non-null  float64
#  39  rdata_VirtualAddress     17079 non-null  float64
#  40  rdata_SizeOfRawData      17079 non-null  float64
#  41  rdata_PointerToRawData   17079 non-null  float64
#  42  rdata_Characteristics    17079 non-null  object
#  43  registry_read            17079 non-null  float64
#  44  registry_write           17079 non-null  float64
#  45  registry_delete          17079 non-null  float64
#  46  network_dns              17079 non-null  float64
#  47  network_http             17079 non-null  float64
#  48  network_connections      17079 non-null  float64
#  49  files_suspicious         17079 non-null  float64
#  50  files_text               17079 non-null  float64
#  51  files_unknown            17079 non-null  float64
#  52  dlls_calls               17079 non-null  float64
#  53  apis                     17079 non-null  float64
# dtypes: float64(48), object(6)
# memory usage: 7.2+ MB

# %% [markdown]
# ### Convertir las variables categoricas
# Hay 6 variables categoricas
# One-Hot Encoding a MachineType, Subsystem, PEType.
#
# Multi-Label Binarization a DllCharacteristics, text_Characteristics, rdata_Characteristics.

# %%
import ast

# === Variables categóricas ===
categorical_single = ["MachineType", "Subsystem", "PEType"]  # One-Hot Encoding
categorical_multi  = ["DllCharacteristics", "text_Characteristics", "rdata_Characteristics"]  # Multi-Label Binarization

# === 1. Categorías simples (One-Hot) ===
for col in categorical_single:
    if col in X.columns:
        print(f"\n▶ {col} (categorías únicas):")
        print(X[col].unique())

# === 2. Categorías multilabel ===
for col in categorical_multi:
    if col in X.columns:
        print(f"\n▶ {col} (categorías posibles):")
        categorias = set()
        for row in X[col].dropna():
            if isinstance(row, str):
                try:
                    # Convierte el string de lista a lista real
                    items = ast.literal_eval(row)
                    categorias.update(items)
                except:
                    pass
        print(sorted(categorias))
        print(f"Total categorías en {col}: {len(categorias)}")
# Out:
# ▶ MachineType (categorías únicas):
# ['AMD64' 'Intel386']
#
# ▶ Subsystem (categorías únicas):
# ['IMAGE_SUBSYSTEM_WINDOWS_GUI' 'IMAGE_SUBSYSTEM_WINDOWS_CUI'
#  'IMAGE_SUBSYSTEM_NATIVE' 'IMAGE_SUBSYSTEM_UNKNOWN']
#
# ▶ PEType (categorías únicas):
# ['PE32+' 'PE32']
#
# ▶ DllCharacteristics (categorías posibles):
# ['IMAGE_DLLCHARACTERISTICS_APPCONTAINER', 'IMAGE_DLLCHARACTERISTICS_DYNAMIC_BASE', 'IMAGE_DLLCHARACTERISTICS_FORCE_INTEGRITY', 'IMAGE_DLLCHARACTERISTICS_GUARD_CF', 'IMAGE_DLLCHARACTERISTICS_HIGH_ENTROPY_VA', 'IMAGE_DLLCHARACTERISTICS_NO_BIND', 'IMAGE_DLLCHARACTERISTICS_NO_ISOLATION', 'IMAGE_DLLCHARACTERISTICS_NO_SEH', 'IMAGE_DLLCHARACTERISTICS_NX_COMPAT', 'IMAGE_DLLCHARACTERISTICS_TERMINAL_SERVER_AWARE', 'IMAGE_LIBRARY_PROCESS_INIT', 'IMAGE_LIBRARY_PROCESS_TERM', 'IMAGE_LIBRARY_THREAD_INIT']
# Total categorías en DllCharacteristics: 13
#
# ▶ text_Characteristics (categorías posibles):
# ['IMAGE_SCN_ALIGN_1024BYTES', 'IMAGE_SCN_ALIGN_128BYTES', 'IMAGE_SCN_ALIGN_16BYTES', 'IMAGE_SCN_ALIGN_1BYTES', 'IMAGE_SCN_ALIGN_2048BYTES', 'IMAGE_SCN_ALIGN_256BYTES', 'IMAGE_SCN_ALIGN_2BYTES', 'IMAGE_SCN_ALIGN_32BYTES', 'IMAGE_SCN_ALIGN_4096BYTES', 'IMAGE_SCN_ALIGN_4BYTES', 'IMAGE_SCN_ALIGN_512BYTES', 'IMAGE_SCN_ALIGN_64BYTES', 'IMAGE_SCN_ALIGN_8192BYTES', 'IMAGE_SCN_ALIGN_8BYTES', 'IMAGE_SCN_ALIGN_MASK', 'IMAGE_SCN_CNT_CODE', 'IMAGE_SCN_CNT_INITIALIZED_DATA', 'IMAGE_SCN_CNT_UNINITIALIZED_DATA', 'IMAGE_SCN_GPREL', 'IMAGE_SCN_LNK_COMDAT', 'IMAGE_SCN_LNK_INFO', 'IMAGE_SCN_LNK_OTHER', 'IMAGE_SCN_LNK_REMOVE', 'IMAGE_SCN_MEM_EXECUTE', 'IMAGE_SCN_MEM_LOCKED', 'IMAGE_SCN_MEM_NOT_PAGED', 'IMAGE_SCN_MEM_PRELOAD', 'IMAGE_SCN_MEM_PURGEABLE', 'IMAGE_SCN_MEM_READ', 'IMAGE_SCN_MEM_SHARED', 'IMAGE_SCN_MEM_WRITE', 'IMAGE_SCN_NO_DEFER_SPEC_EXC', 'IMAGE_SCN_TYPE_DSECT', 'IMAGE_SCN_TYPE_GROUP', 'IMAGE_SCN_TYPE_NOLOAD', 'IMAGE_SCN_TYPE_NO_PAD', 'IMAGE_SCN_TYPE_OVER']
# Total categorías en text_Characteristics: 37
#
# ▶ rdata_Characteristics (categorías posibles):
# ['IMAGE_SCN_ALIGN_1024BYTES', 'IMAGE_SCN_ALIGN_128BYTES', 'IMAGE_SCN_ALIGN_16BYTES', 'IMAGE_SCN_ALIGN_1BYTES', 'IMAGE_SCN_ALIGN_2048BYTES', 'IMAGE_SCN_ALIGN_256BYTES', 'IMAGE_SCN_ALIGN_2BYTES', 'IMAGE_SCN_ALIGN_32BYTES', 'IMAGE_SCN_ALIGN_4096BYTES', 'IMAGE_SCN_ALIGN_4BYTES', 'IMAGE_SCN_ALIGN_512BYTES', 'IMAGE_SCN_ALIGN_64BYTES', 'IMAGE_SCN_ALIGN_8192BYTES', 'IMAGE_SCN_ALIGN_8BYTES', 'IMAGE_SCN_ALIGN_MASK', 'IMAGE_SCN_CNT_CODE', 'IMAGE_SCN_CNT_INITIALIZED_DATA', 'IMAGE_SCN_CNT_UNINITIALIZED_DATA', 'IMAGE_SCN_GPREL', 'IMAGE_SCN_LNK_COMDAT', 'IMAGE_SCN_LNK_INFO', 'IMAGE_SCN_LNK_OTHER', 'IMAGE_SCN_LNK_REMOVE', 'IMAGE_SCN_MEM_EXECUTE', 'IMAGE_SCN_MEM_LOCKED', 'IMAGE_SCN_MEM_NOT_PAGED', 'IMAGE_SCN_MEM_PRELOAD', 'IMAGE_SCN_MEM_PURGEABLE', 'IMAGE_SCN_MEM_READ', 'IMAGE_SCN_MEM_SHARED', 'IMAGE_SCN_MEM_WRITE', 'IMAGE_SCN_NO_DEFER_SPEC_EXC', 'IMAGE_SCN_TYPE_COPY', 'IMAGE_SCN_TYPE_DSECT', 'IMAGE_SCN_TYPE_GROUP', 'IMAGE_SCN_TYPE_NOLOAD', 'IMAGE_SCN_TYPE_NO_PAD', 'IMAGE_SCN_TYPE_OVER']
# Total categorías en rdata_Characteristics: 38

# %% [markdown]
# ### Aplicacion de one Hot Encoder
# Variables:
# MachineType,
# Subsystem
# PEType

# %%
# Variables categóricas de una sola categoría por fila
categorical_single = ["MachineType", "Subsystem", "PEType"]

# Crear el encoder
ohe = OneHotEncoder(sparse_output=False, handle_unknown="ignore")

# Ajustar y transformar sobre X
encoded_array = ohe.fit_transform(X[categorical_single])

# Convertir a DataFrame con nombres de columnas
encoded_df = pd.DataFrame(
    encoded_array, 
    columns=ohe.get_feature_names_out(categorical_single), 
    index=X.index
)

# Concatenar al dataset original, eliminando las columnas viejas
X = pd.concat([X.drop(columns=categorical_single), encoded_df], axis=1)

# (opcional) optimizar memoria: pasar a uint8 en vez de float64
X[encoded_df.columns] = X[encoded_df.columns].astype("uint8")

# Verificación
print("Shape final de X:", X.shape)
print("Columnas nuevas:", encoded_df.columns.tolist())
print("Categóricas que quedan:", X.select_dtypes(include="object").columns.tolist())
# Out:
# Shape final de X: (17079, 59)
# Columnas nuevas: ['MachineType_AMD64', 'MachineType_Intel386', 'Subsystem_IMAGE_SUBSYSTEM_NATIVE', 'Subsystem_IMAGE_SUBSYSTEM_UNKNOWN', 'Subsystem_IMAGE_SUBSYSTEM_WINDOWS_CUI', 'Subsystem_IMAGE_SUBSYSTEM_WINDOWS_GUI', 'PEType_PE32', 'PEType_PE32+']
# Categóricas que quedan: ['DllCharacteristics', 'text_Characteristics', 'rdata_Characteristics']

# %% [markdown]
# ### Aplicar Multi-Label Binarization
# DllCharacteristics', 'text_Characteristics', 'rdata_Characteristics

# %%
import pandas as pd
import numpy as np
import ast
from sklearn.preprocessing import MultiLabelBinarizer

multilabel_cols = ["DllCharacteristics", "text_Characteristics", "rdata_Characteristics"]
multilabel_cols = [c for c in multilabel_cols if c in X.columns]

def _to_list(cell):
    """Convierte celda a lista de strings limpia."""
    if isinstance(cell, list):
        return [str(x).strip() for x in cell if str(x).strip() != ""]
    if isinstance(cell, str):
        s = cell.strip()
        if s == "" or s.upper() in {"NAN", "NONE", "NULL"}:
            return []
        # casos como "[]", "['A', 'B']"
        try:
            parsed = ast.literal_eval(s)
            if isinstance(parsed, (list, tuple, set)):
                return [str(x).strip() for x in parsed if str(x).strip() != ""]
            return [s] if s != "" else []
        except Exception:
            return [s]
    # NaN u otros tipos
    return []

nuevas_cols_totales = []

for col in multilabel_cols:
    listas = X[col].apply(_to_list)

    mlb = MultiLabelBinarizer()
    encoded = mlb.fit_transform(listas)

    prefijo = f"{col}_"
    cols_out = [prefijo + cls for cls in mlb.classes_]
    encoded_df = pd.DataFrame(encoded, columns=cols_out, index=X.index)

    # <<< CLAVE: asegurar 0/1 sin vacíos >>>
    encoded_df = encoded_df.fillna(0).astype("uint8")

    # concatenar y eliminar la original
    X = pd.concat([X.drop(columns=[col]), encoded_df], axis=1)
    nuevas_cols_totales.extend(cols_out)

    print(f"{col}: {len(cols_out)} columnas creadas (sin NaN).")

print("\nTotal de columnas nuevas (multilabel):", len(nuevas_cols_totales))
print("Columnas object restantes:", X.select_dtypes(include="object").columns.tolist())
# Out:
# DllCharacteristics: 14 columnas creadas (sin NaN).
# text_Characteristics: 38 columnas creadas (sin NaN).
# rdata_Characteristics: 39 columnas creadas (sin NaN).
#
# Total de columnas nuevas (multilabel): 91
# Columnas object restantes: []

# %%
print("Columnas object restantes:", X.select_dtypes(include="object").columns.tolist())
# Out:
# Columnas object restantes: []

# %%
# Conteo de nulos por columna
print(X.isnull().sum()[X.isnull().sum() > 0])
# Out:
# Series([], dtype: int64)

# %%
# Conteo de valores nulos por columna
print(X.isnull().sum())
# Out:
# EntryPoint                                     0
# bytes_on_last_page                             0
# pages_in_file                                  0
# relocations                                    0
# size_of_header                                 0
#                                               ..
# rdata_Characteristics_IMAGE_SCN_TYPE_DSECT     0
# rdata_Characteristics_IMAGE_SCN_TYPE_GROUP     0
# rdata_Characteristics_IMAGE_SCN_TYPE_NOLOAD    0
# rdata_Characteristics_IMAGE_SCN_TYPE_NO_PAD    0
# rdata_Characteristics_IMAGE_SCN_TYPE_OVER      0
# Length: 147, dtype: int64

# %%
# === Exportar X a CSV ===
#X.to_csv("dataset_final.csv", index=False, encoding="utf-8")

#print("Archivo CSV guardado como: dataset_final.csv")

# %%
print(X.isnull().sum())
# Out:
# EntryPoint                                     0
# bytes_on_last_page                             0
# pages_in_file                                  0
# relocations                                    0
# size_of_header                                 0
#                                               ..
# rdata_Characteristics_IMAGE_SCN_TYPE_DSECT     0
# rdata_Characteristics_IMAGE_SCN_TYPE_GROUP     0
# rdata_Characteristics_IMAGE_SCN_TYPE_NOLOAD    0
# rdata_Characteristics_IMAGE_SCN_TYPE_NO_PAD    0
# rdata_Characteristics_IMAGE_SCN_TYPE_OVER      0
# Length: 147, dtype: int64

# %% [markdown]
# ### Seleccion de caracteristicas
# Los métodos de selección de características se pueden clasificar en tres categorías generales:
#
# Métodos de filtrado: Los métodos de filtrado utilizan técnicas estadísticas para evaluar la relevancia de las características independientemente del modelo. Entre las técnicas más comunes se incluyen los coeficientes de correlación, las pruebas de chi-cuadrado y la información mutua.

# %%
# === 1. Calcular matriz de correlación (Pearson) ===
corr_matrix = X.corr(method="pearson").abs()

# === 2. Visualización opcional ===
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, cmap="coolwarm", center=0)
plt.title("Matriz de correlación (Pearson)")
plt.show()

# %%
# === 3. Mantener solo parte superior de la matriz (para evitar duplicados)
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# === 4. Definir umbral (ejemplo: 0.95)
umbral = 0.95

# === 5. Detectar pares de columnas altamente correlacionadas
correlated_pairs = [
    (col, row, upper.loc[row, col])
    for col in upper.columns
    for row in upper.index
    if upper.loc[row, col] > umbral
]

# === 6. Mostrar resultados
print(f"Número de pares de columnas con correlación > {umbral}: {len(correlated_pairs)}")
print("Ejemplos de pares correlacionados:")
for pair in correlated_pairs:
    print(pair)
# Out:
# Número de pares de columnas con correlación > 0.95: 125
# Ejemplos de pares correlacionados:
# ('AddressOfEntryPoint', 'EntryPoint', 0.9594593038095964)
# ('MachineType_Intel386', 'MachineType_AMD64', 0.9999999999999999)
# ('PEType_PE32+', 'PEType_PE32', 1.0000000000000004)
# ('DllCharacteristics_0', 'Subsystem_IMAGE_SUBSYSTEM_UNKNOWN', 0.9969862284523479)
# ('text_Characteristics_0', 'Subsystem_IMAGE_SUBSYSTEM_UNKNOWN', 0.9969862284523479)
# ('text_Characteristics_0', 'DllCharacteristics_0', 1.0)
# ('text_Characteristics_IMAGE_SCN_ALIGN_16BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_1024BYTES', 1.0)
# ('text_Characteristics_IMAGE_SCN_ALIGN_1BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_1024BYTES', 0.9881959356711576)
# ('text_Characteristics_IMAGE_SCN_ALIGN_1BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_16BYTES', 0.9881959356711576)
# ('text_Characteristics_IMAGE_SCN_ALIGN_256BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_1024BYTES', 0.9881959356711576)
# ('text_Characteristics_IMAGE_SCN_ALIGN_256BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_16BYTES', 0.9881959356711576)
# ('text_Characteristics_IMAGE_SCN_ALIGN_256BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_1BYTES', 1.0)
# ('text_Characteristics_IMAGE_SCN_ALIGN_32BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_1024BYTES', 0.9989320237017981)
# ('text_Characteristics_IMAGE_SCN_ALIGN_32BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_16BYTES', 0.9989320237017981)
# ('text_Characteristics_IMAGE_SCN_ALIGN_32BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_1BYTES', 0.9870912440761597)
# ('text_Characteristics_IMAGE_SCN_ALIGN_32BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_256BYTES', 0.9870912440761597)
# ('text_Characteristics_IMAGE_SCN_ALIGN_4096BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_1024BYTES', 1.0)
# ('text_Characteristics_IMAGE_SCN_ALIGN_4096BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_16BYTES', 1.0)
# ('text_Characteristics_IMAGE_SCN_ALIGN_4096BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_1BYTES', 0.9881959356711577)
# ('text_Characteristics_IMAGE_SCN_ALIGN_4096BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_256BYTES', 0.9881959356711577)
# ('text_Characteristics_IMAGE_SCN_ALIGN_4096BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_32BYTES', 0.9989320237017981)
# ('text_Characteristics_IMAGE_SCN_ALIGN_4BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_1024BYTES', 1.0)
# ('text_Characteristics_IMAGE_SCN_ALIGN_4BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_16BYTES', 1.0)
# ('text_Characteristics_IMAGE_SCN_ALIGN_4BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_1BYTES', 0.9881959356711577)
# ('text_Characteristics_IMAGE_SCN_ALIGN_4BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_256BYTES', 0.9881959356711577)
# ('text_Characteristics_IMAGE_SCN_ALIGN_4BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_32BYTES', 0.9989320237017981)
# ('text_Characteristics_IMAGE_SCN_ALIGN_4BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_4096BYTES', 1.0)
# ('text_Characteristics_IMAGE_SCN_ALIGN_512BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_2BYTES', 0.9572299933072712)
# ('text_Characteristics_IMAGE_SCN_ALIGN_64BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_1024BYTES', 1.0)
# ('text_Characteristics_IMAGE_SCN_ALIGN_64BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_16BYTES', 1.0)
# ('text_Characteristics_IMAGE_SCN_ALIGN_64BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_1BYTES', 0.9881959356711577)
# ('text_Characteristics_IMAGE_SCN_ALIGN_64BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_256BYTES', 0.9881959356711577)
# ('text_Characteristics_IMAGE_SCN_ALIGN_64BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_32BYTES', 0.9989320237017981)
# ('text_Characteristics_IMAGE_SCN_ALIGN_64BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_4096BYTES', 1.0)
# ('text_Characteristics_IMAGE_SCN_ALIGN_64BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_4BYTES', 1.0)
# ('text_Characteristics_IMAGE_SCN_ALIGN_8192BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_1024BYTES', 0.9989320237017981)
# ('text_Characteristics_IMAGE_SCN_ALIGN_8192BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_16BYTES', 0.9989320237017981)
# ('text_Characteristics_IMAGE_SCN_ALIGN_8192BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_1BYTES', 0.9870912440761597)
# ('text_Characteristics_IMAGE_SCN_ALIGN_8192BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_256BYTES', 0.9870912440761597)
# ('text_Characteristics_IMAGE_SCN_ALIGN_8192BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_32BYTES', 1.0)
# ('text_Characteristics_IMAGE_SCN_ALIGN_8192BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_4096BYTES', 0.9989320237017981)
# ('text_Characteristics_IMAGE_SCN_ALIGN_8192BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_4BYTES', 0.9989320237017981)
# ('text_Characteristics_IMAGE_SCN_ALIGN_8192BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_64BYTES', 0.9989320237017981)
# ('text_Characteristics_IMAGE_SCN_ALIGN_8BYTES', 'text_Characteristics_IMAGE_SCN_ALIGN_2048BYTES', 0.9987928504296928)
# ('text_Characteristics_IMAGE_SCN_ALIGN_MASK', 'text_Characteristics_IMAGE_SCN_ALIGN_1024BYTES', 1.0)
# ('text_Characteristics_IMAGE_SCN_ALIGN_MASK', 'text_Characteristics_IMAGE_SCN_ALIGN_16BYTES', 1.0)
# ('text_Characteristics_IMAGE_SCN_ALIGN_MASK', 'text_Characteristics_IMAGE_SCN_ALIGN_1BYTES', 0.9881959356711577)
# ('text_Characteristics_IMAGE_SCN_ALIGN_MASK', 'text_Characteristics_IMAGE_SCN_ALIGN_256BYTES', 0.9881959356711577)
# ('text_Characteristics_IMAGE_SCN_ALIGN_MASK', 'text_Characteristics_IMAGE_SCN_ALIGN_32BYTES', 0.9989320237017981)
# ('text_Characteristics_IMAGE_SCN_ALIGN_MASK', 'text_Characteristics_IMAGE_SCN_ALIGN_4096BYTES', 1.0)
# ('text_Characteristics_IMAGE_SCN_ALIGN_MASK', 'text_Characteristics_IMAGE_SCN_ALIGN_4BYTES', 1.0)
# ('text_Characteristics_IMAGE_SCN_ALIGN_MASK', 'text_Characteristics_IMAGE_SCN_ALIGN_64BYTES', 1.0)
# ('text_Characteristics_IMAGE_SCN_ALIGN_MASK', 'text_Characteristics_IMAGE_SCN_ALIGN_8192BYTES', 0.9989320237017981)
# ('text_Characteristics_IMAGE_SCN_MEM_READ', 'Subsystem_IMAGE_SUBSYSTEM_UNKNOWN', 0.9969862284523479)
# ('text_Characteristics_IMAGE_SCN_MEM_READ', 'DllCharacteristics_0', 1.0)
# ('text_Characteristics_IMAGE_SCN_MEM_READ', 'text_Characteristics_0', 1.0)
# ('rdata_Characteristics_0', 'Subsystem_IMAGE_SUBSYSTEM_UNKNOWN', 0.9969862284523479)
# ('rdata_Characteristics_0', 'DllCharacteristics_0', 1.0)
# ('rdata_Characteristics_0', 'text_Characteristics_0', 1.0)
# ('rdata_Characteristics_0', 'text_Characteristics_IMAGE_SCN_MEM_READ', 1.0)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_16BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_1024BYTES', 0.9927813199624397)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_256BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_1BYTES', 0.9879145736396543)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_2BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_1024BYTES', 0.960138474970261)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_2BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_16BYTES', 0.9655562215685852)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_32BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_1024BYTES', 0.9927813199624397)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_32BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_16BYTES', 1.0)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_32BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_2BYTES', 0.9655562215685852)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_4096BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_1024BYTES', 0.9992012446006749)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_4096BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_16BYTES', 0.9935947154074108)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_4096BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_2BYTES', 0.9593715591792864)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_4096BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_32BYTES', 0.9935947154074108)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_4BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_1024BYTES', 0.9927808999092341)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_4BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_16BYTES', 0.9983828370084866)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_4BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_2BYTES', 0.9671202125847169)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_4BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_32BYTES', 0.9983828370084866)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_4BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_4096BYTES', 0.991987910805095)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_512BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_1024BYTES', 0.9716699360781803)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_512BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_16BYTES', 0.963944550938727)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_512BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_2BYTES', 0.9881323269561487)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_512BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_32BYTES', 0.963944550938727)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_512BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_4096BYTES', 0.9708938094703822)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_512BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_4BYTES', 0.9638540429387564)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_64BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_1024BYTES', 0.9927813199624397)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_64BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_16BYTES', 1.0)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_64BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_2BYTES', 0.9655562215685852)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_64BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_32BYTES', 1.0)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_64BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_4096BYTES', 0.9935947154074108)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_64BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_4BYTES', 0.9983828370084866)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_64BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_512BYTES', 0.963944550938727)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_8192BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_1024BYTES', 0.9992012446006749)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_8192BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_16BYTES', 0.9935947154074108)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_8192BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_2BYTES', 0.9593715591792864)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_8192BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_32BYTES', 0.9935947154074108)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_8192BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_4096BYTES', 1.0)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_8192BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_4BYTES', 0.991987910805095)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_8192BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_512BYTES', 0.9708938094703822)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_8192BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_64BYTES', 0.9935947154074108)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_8BYTES', 'rdata_Characteristics_IMAGE_SCN_ALIGN_2048BYTES', 0.9892086785987803)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_MASK', 'rdata_Characteristics_IMAGE_SCN_ALIGN_1024BYTES', 0.9992012446006749)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_MASK', 'rdata_Characteristics_IMAGE_SCN_ALIGN_16BYTES', 0.9935947154074108)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_MASK', 'rdata_Characteristics_IMAGE_SCN_ALIGN_2BYTES', 0.9593715591792864)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_MASK', 'rdata_Characteristics_IMAGE_SCN_ALIGN_32BYTES', 0.9935947154074108)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_MASK', 'rdata_Characteristics_IMAGE_SCN_ALIGN_4096BYTES', 1.0)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_MASK', 'rdata_Characteristics_IMAGE_SCN_ALIGN_4BYTES', 0.991987910805095)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_MASK', 'rdata_Characteristics_IMAGE_SCN_ALIGN_512BYTES', 0.9708938094703822)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_MASK', 'rdata_Characteristics_IMAGE_SCN_ALIGN_64BYTES', 0.9935947154074108)
# ('rdata_Characteristics_IMAGE_SCN_ALIGN_MASK', 'rdata_Characteristics_IMAGE_SCN_ALIGN_8192BYTES', 1.0)
# ('rdata_Characteristics_IMAGE_SCN_CNT_INITIALIZED_DATA', 'Subsystem_IMAGE_SUBSYSTEM_UNKNOWN', 0.9639415974295837)
# ('rdata_Characteristics_IMAGE_SCN_CNT_INITIALIZED_DATA', 'DllCharacteristics_0', 0.9668635325579994)
# ('rdata_Characteristics_IMAGE_SCN_CNT_INITIALIZED_DATA', 'text_Characteristics_0', 0.9668635325579994)
# ('rdata_Characteristics_IMAGE_SCN_CNT_INITIALIZED_DATA', 'text_Characteristics_IMAGE_SCN_MEM_READ', 0.9668635325579992)
# ('rdata_Characteristics_IMAGE_SCN_CNT_INITIALIZED_DATA', 'rdata_Characteristics_0', 0.9668635325579994)
# ('rdata_Characteristics_IMAGE_SCN_LNK_REMOVE', 'rdata_Characteristics_IMAGE_SCN_LNK_INFO', 1.0)
# ('rdata_Characteristics_IMAGE_SCN_MEM_LOCKED', 'text_Characteristics_IMAGE_SCN_MEM_PRELOAD', 1.0)
# ('rdata_Characteristics_IMAGE_SCN_MEM_PRELOAD', 'text_Characteristics_IMAGE_SCN_MEM_PRELOAD', 1.0)
# ('rdata_Characteristics_IMAGE_SCN_MEM_PRELOAD', 'rdata_Characteristics_IMAGE_SCN_MEM_LOCKED', 1.0)
# ('rdata_Characteristics_IMAGE_SCN_MEM_READ', 'Subsystem_IMAGE_SUBSYSTEM_UNKNOWN', 0.9969862284523479)
# ('rdata_Characteristics_IMAGE_SCN_MEM_READ', 'DllCharacteristics_0', 1.0)
# ('rdata_Characteristics_IMAGE_SCN_MEM_READ', 'text_Characteristics_0', 1.0)
# ('rdata_Characteristics_IMAGE_SCN_MEM_READ', 'text_Characteristics_IMAGE_SCN_MEM_READ', 1.0)
# ('rdata_Characteristics_IMAGE_SCN_MEM_READ', 'rdata_Characteristics_0', 1.0)
# ('rdata_Characteristics_IMAGE_SCN_MEM_READ', 'rdata_Characteristics_IMAGE_SCN_CNT_INITIALIZED_DATA', 0.9668635325579992)
# ('rdata_Characteristics_IMAGE_SCN_TYPE_NOLOAD', 'rdata_Characteristics_IMAGE_SCN_TYPE_COPY', 0.9573990599144154)
# ('rdata_Characteristics_IMAGE_SCN_TYPE_NO_PAD', 'rdata_Characteristics_IMAGE_SCN_TYPE_COPY', 0.9573990599144154)
# ('rdata_Characteristics_IMAGE_SCN_TYPE_NO_PAD', 'rdata_Characteristics_IMAGE_SCN_TYPE_NOLOAD', 1.0)

# %% [markdown]
# ### F-TEST

# %%
from sklearn.feature_selection import f_classif
import numpy as np

def calcular_f_test_y_pvalues(X, y, alpha=0.05):
    # Asegurarse de tomar solo variables numéricas
    X_num = X.select_dtypes(include=[np.number])
    
    # Calcular F-test
    F, p = f_classif(X_num, y)
    
    resultados = []
    for feature, f_val, p_val in zip(X_num.columns, F, p):
        if p_val < alpha:
            resultados.append(f"La variable {feature} es linealmente DEPENDIENTE de la clase. p-value: {p_val:.2e}")
        else:
            resultados.append(f"La variable {feature} es linealmente INDEPENDIENTE de la clase. p-value: {p_val:.2e}")
    
    return resultados

# === Ejecución ===
resultados = calcular_f_test_y_pvalues(X, y)

for r in resultados:  
    print(r)
# Out:
# La variable EntryPoint es linealmente DEPENDIENTE de la clase. p-value: 3.94e-03
# La variable bytes_on_last_page es linealmente DEPENDIENTE de la clase. p-value: 3.73e-04
# La variable pages_in_file es linealmente DEPENDIENTE de la clase. p-value: 1.57e-07
# La variable relocations es linealmente DEPENDIENTE de la clase. p-value: 9.38e-04
# La variable size_of_header es linealmente DEPENDIENTE de la clase. p-value: 6.96e-03
# La variable min_extra_paragraphs es linealmente DEPENDIENTE de la clase. p-value: 8.13e-06
# La variable max_extra_paragraphs es linealmente DEPENDIENTE de la clase. p-value: 0.00e+00
# La variable init_ss_value es linealmente DEPENDIENTE de la clase. p-value: 1.24e-06
# La variable init_sp_value es linealmente DEPENDIENTE de la clase. p-value: 9.99e-04
# La variable init_ip_value es linealmente DEPENDIENTE de la clase. p-value: 9.43e-04
# La variable init_cs_value es linealmente DEPENDIENTE de la clase. p-value: 6.54e-04
# La variable over_lay_number es linealmente DEPENDIENTE de la clase. p-value: 1.53e-03
# La variable SizeOfCode es linealmente INDEPENDIENTE de la clase. p-value: 1.51e-01
# La variable SizeOfInitializedData es linealmente INDEPENDIENTE de la clase. p-value: 4.23e-01
# La variable SizeOfUninitializedData es linealmente DEPENDIENTE de la clase. p-value: 9.31e-03
# La variable AddressOfEntryPoint es linealmente DEPENDIENTE de la clase. p-value: 1.23e-03
# La variable BaseOfCode es linealmente INDEPENDIENTE de la clase. p-value: 1.82e-01
# La variable BaseOfData es linealmente INDEPENDIENTE de la clase. p-value: 1.92e-01
# La variable ImageBase es linealmente INDEPENDIENTE de la clase. p-value: 1.76e-01
# La variable SectionAlignment es linealmente DEPENDIENTE de la clase. p-value: 0.00e+00
# La variable FileAlignment es linealmente DEPENDIENTE de la clase. p-value: 1.30e-50
# La variable SizeOfImage es linealmente DEPENDIENTE de la clase. p-value: 1.96e-09
# La variable SizeOfHeaders es linealmente DEPENDIENTE de la clase. p-value: 2.69e-07
# La variable Checksum es linealmente DEPENDIENTE de la clase. p-value: 7.15e-20
# La variable SizeofStackReserve es linealmente DEPENDIENTE de la clase. p-value: 1.72e-21
# La variable SizeofStackCommit es linealmente DEPENDIENTE de la clase. p-value: 1.69e-51
# La variable SizeofHeapCommit es linealmente DEPENDIENTE de la clase. p-value: 2.05e-04
# La variable SizeofHeapReserve es linealmente DEPENDIENTE de la clase. p-value: 5.44e-151
# La variable LoaderFlags es linealmente INDEPENDIENTE de la clase. p-value: 2.37e-01
# La variable text_VirtualSize es linealmente DEPENDIENTE de la clase. p-value: 1.94e-128
# La variable text_VirtualAddress es linealmente INDEPENDIENTE de la clase. p-value: 7.23e-02
# La variable text_SizeOfRawData es linealmente DEPENDIENTE de la clase. p-value: 1.27e-133
# La variable text_PointerToRawData es linealmente DEPENDIENTE de la clase. p-value: 1.57e-02
# La variable rdata_VirtualSize es linealmente DEPENDIENTE de la clase. p-value: 1.88e-41
# La variable rdata_VirtualAddress es linealmente DEPENDIENTE de la clase. p-value: 6.72e-15
# La variable rdata_SizeOfRawData es linealmente DEPENDIENTE de la clase. p-value: 7.28e-32
# La variable rdata_PointerToRawData es linealmente DEPENDIENTE de la clase. p-value: 6.93e-120
# La variable registry_read es linealmente DEPENDIENTE de la clase. p-value: 2.76e-18
# La variable registry_write es linealmente DEPENDIENTE de la clase. p-value: 1.65e-35
# La variable registry_delete es linealmente DEPENDIENTE de la clase. p-value: 5.51e-17
# La variable network_dns es linealmente DEPENDIENTE de la clase. p-value: 6.04e-94
# La variable network_http es linealmente DEPENDIENTE de la clase. p-value: 8.80e-37
# La variable network_connections es linealmente DEPENDIENTE de la clase. p-value: 1.02e-77
# La variable files_suspicious es linealmente DEPENDIENTE de la clase. p-value: 0.00e+00
# La variable files_text es linealmente DEPENDIENTE de la clase. p-value: 0.00e+00
# La variable files_unknown es linealmente DEPENDIENTE de la clase. p-value: 6.17e-200
# La variable dlls_calls es linealmente DEPENDIENTE de la clase. p-value: 3.32e-14
# La variable apis es linealmente DEPENDIENTE de la clase. p-value: 5.59e-37
# La variable MachineType_AMD64 es linealmente DEPENDIENTE de la clase. p-value: 2.86e-254
# La variable MachineType_Intel386 es linealmente DEPENDIENTE de la clase. p-value: 2.86e-254
# La variable Subsystem_IMAGE_SUBSYSTEM_NATIVE es linealmente DEPENDIENTE de la clase. p-value: 5.71e-12
# La variable Subsystem_IMAGE_SUBSYSTEM_UNKNOWN es linealmente DEPENDIENTE de la clase. p-value: 0.00e+00
# La variable Subsystem_IMAGE_SUBSYSTEM_WINDOWS_CUI es linealmente DEPENDIENTE de la clase. p-value: 0.00e+00
# La variable Subsystem_IMAGE_SUBSYSTEM_WINDOWS_GUI es linealmente DEPENDIENTE de la clase. p-value: 0.00e+00
# La variable PEType_PE32 es linealmente DEPENDIENTE de la clase. p-value: 1.27e-301
# La variable PEType_PE32+ es linealmente DEPENDIENTE de la clase. p-value: 1.27e-301
# La variable DllCharacteristics_0 es linealmente DEPENDIENTE de la clase. p-value: 0.00e+00
# La variable DllCharacteristics_IMAGE_DLLCHARACTERISTICS_APPCONTAINER es linealmente DEPENDIENTE de la clase. p-value: 1.82e-02
# La variable DllCharacteristics_IMAGE_DLLCHARACTERISTICS_DYNAMIC_BASE es linealmente DEPENDIENTE de la clase. p-value: 0.00e+00
# La variable DllCharacteristics_IMAGE_DLLCHARACTERISTICS_FORCE_INTEGRITY es linealmente DEPENDIENTE de la clase. p-value: 3.27e-03
# La variable DllCharacteristics_IMAGE_DLLCHARACTERISTICS_GUARD_CF es linealmente DEPENDIENTE de la clase. p-value: 1.37e-04
# La variable DllCharacteristics_IMAGE_DLLCHARACTERISTICS_HIGH_ENTROPY_VA es linealmente DEPENDIENTE de la clase. p-value: 0.00e+00
# La variable DllCharacteristics_IMAGE_DLLCHARACTERISTICS_NO_BIND es linealmente DEPENDIENTE de la clase. p-value: 9.90e-03
# La variable DllCharacteristics_IMAGE_DLLCHARACTERISTICS_NO_ISOLATION es linealmente DEPENDIENTE de la clase. p-value: 1.00e-20
# La variable DllCharacteristics_IMAGE_DLLCHARACTERISTICS_NO_SEH es linealmente DEPENDIENTE de la clase. p-value: 1.55e-110
# La variable DllCharacteristics_IMAGE_DLLCHARACTERISTICS_NX_COMPAT es linealmente DEPENDIENTE de la clase. p-value: 6.72e-256
# La variable DllCharacteristics_IMAGE_DLLCHARACTERISTICS_TERMINAL_SERVER_AWARE es linealmente DEPENDIENTE de la clase. p-value: 4.18e-305
# La variable DllCharacteristics_IMAGE_LIBRARY_PROCESS_INIT es linealmente DEPENDIENTE de la clase. p-value: 3.63e-43
# La variable DllCharacteristics_IMAGE_LIBRARY_PROCESS_TERM es linealmente DEPENDIENTE de la clase. p-value: 4.65e-55
# La variable DllCharacteristics_IMAGE_LIBRARY_THREAD_INIT es linealmente DEPENDIENTE de la clase. p-value: 7.11e-22
# La variable text_Characteristics_0 es linealmente DEPENDIENTE de la clase. p-value: 0.00e+00
# La variable text_Characteristics_IMAGE_SCN_ALIGN_1024BYTES es linealmente DEPENDIENTE de la clase. p-value: 3.82e-50
# La variable text_Characteristics_IMAGE_SCN_ALIGN_128BYTES es linealmente INDEPENDIENTE de la clase. p-value: 2.12e-01
# La variable text_Characteristics_IMAGE_SCN_ALIGN_16BYTES es linealmente DEPENDIENTE de la clase. p-value: 3.82e-50
# La variable text_Characteristics_IMAGE_SCN_ALIGN_1BYTES es linealmente DEPENDIENTE de la clase. p-value: 9.25e-49
# La variable text_Characteristics_IMAGE_SCN_ALIGN_2048BYTES es linealmente DEPENDIENTE de la clase. p-value: 3.52e-47
# La variable text_Characteristics_IMAGE_SCN_ALIGN_256BYTES es linealmente DEPENDIENTE de la clase. p-value: 9.25e-49
# La variable text_Characteristics_IMAGE_SCN_ALIGN_2BYTES es linealmente DEPENDIENTE de la clase. p-value: 1.49e-07
# La variable text_Characteristics_IMAGE_SCN_ALIGN_32BYTES es linealmente DEPENDIENTE de la clase. p-value: 5.10e-50
# La variable text_Characteristics_IMAGE_SCN_ALIGN_4096BYTES es linealmente DEPENDIENTE de la clase. p-value: 3.82e-50
# La variable text_Characteristics_IMAGE_SCN_ALIGN_4BYTES es linealmente DEPENDIENTE de la clase. p-value: 3.82e-50
# La variable text_Characteristics_IMAGE_SCN_ALIGN_512BYTES es linealmente DEPENDIENTE de la clase. p-value: 5.64e-08
# La variable text_Characteristics_IMAGE_SCN_ALIGN_64BYTES es linealmente DEPENDIENTE de la clase. p-value: 3.82e-50
# La variable text_Characteristics_IMAGE_SCN_ALIGN_8192BYTES es linealmente DEPENDIENTE de la clase. p-value: 5.10e-50
# La variable text_Characteristics_IMAGE_SCN_ALIGN_8BYTES es linealmente DEPENDIENTE de la clase. p-value: 1.39e-47
# La variable text_Characteristics_IMAGE_SCN_ALIGN_MASK es linealmente DEPENDIENTE de la clase. p-value: 3.82e-50
# La variable text_Characteristics_IMAGE_SCN_CNT_CODE es linealmente DEPENDIENTE de la clase. p-value: 0.00e+00
# La variable text_Characteristics_IMAGE_SCN_CNT_INITIALIZED_DATA es linealmente DEPENDIENTE de la clase. p-value: 9.19e-70
# La variable text_Characteristics_IMAGE_SCN_CNT_UNINITIALIZED_DATA es linealmente DEPENDIENTE de la clase. p-value: 7.52e-08
# La variable text_Characteristics_IMAGE_SCN_GPREL es linealmente DEPENDIENTE de la clase. p-value: 8.26e-15
# La variable text_Characteristics_IMAGE_SCN_LNK_COMDAT es linealmente DEPENDIENTE de la clase. p-value: 9.71e-15
# La variable text_Characteristics_IMAGE_SCN_LNK_INFO es linealmente DEPENDIENTE de la clase. p-value: 9.71e-15
# La variable text_Characteristics_IMAGE_SCN_LNK_OTHER es linealmente DEPENDIENTE de la clase. p-value: 1.33e-03
# La variable text_Characteristics_IMAGE_SCN_LNK_REMOVE es linealmente DEPENDIENTE de la clase. p-value: 1.62e-19
# La variable text_Characteristics_IMAGE_SCN_MEM_EXECUTE es linealmente DEPENDIENTE de la clase. p-value: 0.00e+00
# La variable text_Characteristics_IMAGE_SCN_MEM_LOCKED es linealmente DEPENDIENTE de la clase. p-value: 4.31e-02
# La variable text_Characteristics_IMAGE_SCN_MEM_NOT_PAGED es linealmente DEPENDIENTE de la clase. p-value: 9.44e-16
# La variable text_Characteristics_IMAGE_SCN_MEM_PRELOAD es linealmente INDEPENDIENTE de la clase. p-value: 7.51e-01
# La variable text_Characteristics_IMAGE_SCN_MEM_PURGEABLE es linealmente INDEPENDIENTE de la clase. p-value: 4.24e-01
# La variable text_Characteristics_IMAGE_SCN_MEM_READ es linealmente DEPENDIENTE de la clase. p-value: 0.00e+00
# La variable text_Characteristics_IMAGE_SCN_MEM_SHARED es linealmente INDEPENDIENTE de la clase. p-value: 7.51e-01
# La variable text_Characteristics_IMAGE_SCN_MEM_WRITE es linealmente DEPENDIENTE de la clase. p-value: 1.34e-27
# La variable text_Characteristics_IMAGE_SCN_NO_DEFER_SPEC_EXC es linealmente DEPENDIENTE de la clase. p-value: 3.70e-10
# La variable text_Characteristics_IMAGE_SCN_TYPE_DSECT es linealmente DEPENDIENTE de la clase. p-value: 3.66e-17
# La variable text_Characteristics_IMAGE_SCN_TYPE_GROUP es linealmente DEPENDIENTE de la clase. p-value: 4.54e-03
# La variable text_Characteristics_IMAGE_SCN_TYPE_NOLOAD es linealmente DEPENDIENTE de la clase. p-value: 8.26e-15
# La variable text_Characteristics_IMAGE_SCN_TYPE_NO_PAD es linealmente DEPENDIENTE de la clase. p-value: 9.26e-08
# La variable text_Characteristics_IMAGE_SCN_TYPE_OVER es linealmente DEPENDIENTE de la clase. p-value: 1.94e-12
# La variable rdata_Characteristics_0 es linealmente DEPENDIENTE de la clase. p-value: 0.00e+00
# La variable rdata_Characteristics_IMAGE_SCN_ALIGN_1024BYTES es linealmente DEPENDIENTE de la clase. p-value: 7.13e-71
# La variable rdata_Characteristics_IMAGE_SCN_ALIGN_128BYTES es linealmente INDEPENDIENTE de la clase. p-value: 5.46e-02
# La variable rdata_Characteristics_IMAGE_SCN_ALIGN_16BYTES es linealmente DEPENDIENTE de la clase. p-value: 5.93e-70
# La variable rdata_Characteristics_IMAGE_SCN_ALIGN_1BYTES es linealmente DEPENDIENTE de la clase. p-value: 1.78e-48
# La variable rdata_Characteristics_IMAGE_SCN_ALIGN_2048BYTES es linealmente DEPENDIENTE de la clase. p-value: 5.46e-37
# La variable rdata_Characteristics_IMAGE_SCN_ALIGN_256BYTES es linealmente DEPENDIENTE de la clase. p-value: 5.84e-49
# La variable rdata_Characteristics_IMAGE_SCN_ALIGN_2BYTES es linealmente DEPENDIENTE de la clase. p-value: 6.00e-65
# La variable rdata_Characteristics_IMAGE_SCN_ALIGN_32BYTES es linealmente DEPENDIENTE de la clase. p-value: 5.93e-70
# La variable rdata_Characteristics_IMAGE_SCN_ALIGN_4096BYTES es linealmente DEPENDIENTE de la clase. p-value: 5.27e-71
# La variable rdata_Characteristics_IMAGE_SCN_ALIGN_4BYTES es linealmente DEPENDIENTE de la clase. p-value: 3.46e-70
# La variable rdata_Characteristics_IMAGE_SCN_ALIGN_512BYTES es linealmente DEPENDIENTE de la clase. p-value: 2.74e-66
# La variable rdata_Characteristics_IMAGE_SCN_ALIGN_64BYTES es linealmente DEPENDIENTE de la clase. p-value: 5.93e-70
# La variable rdata_Characteristics_IMAGE_SCN_ALIGN_8192BYTES es linealmente DEPENDIENTE de la clase. p-value: 5.27e-71
# La variable rdata_Characteristics_IMAGE_SCN_ALIGN_8BYTES es linealmente DEPENDIENTE de la clase. p-value: 4.81e-36
# La variable rdata_Characteristics_IMAGE_SCN_ALIGN_MASK es linealmente DEPENDIENTE de la clase. p-value: 5.27e-71
# La variable rdata_Characteristics_IMAGE_SCN_CNT_CODE es linealmente DEPENDIENTE de la clase. p-value: 7.06e-05
# La variable rdata_Characteristics_IMAGE_SCN_CNT_INITIALIZED_DATA es linealmente DEPENDIENTE de la clase. p-value: 0.00e+00
# La variable rdata_Characteristics_IMAGE_SCN_CNT_UNINITIALIZED_DATA es linealmente DEPENDIENTE de la clase. p-value: 1.72e-04
# La variable rdata_Characteristics_IMAGE_SCN_GPREL es linealmente DEPENDIENTE de la clase. p-value: 8.56e-05
# La variable rdata_Characteristics_IMAGE_SCN_LNK_COMDAT es linealmente DEPENDIENTE de la clase. p-value: 1.43e-13
# La variable rdata_Characteristics_IMAGE_SCN_LNK_INFO es linealmente DEPENDIENTE de la clase. p-value: 8.56e-05
# La variable rdata_Characteristics_IMAGE_SCN_LNK_OTHER es linealmente INDEPENDIENTE de la clase. p-value: 2.89e-01
# La variable rdata_Characteristics_IMAGE_SCN_LNK_REMOVE es linealmente DEPENDIENTE de la clase. p-value: 8.56e-05
# La variable rdata_Characteristics_IMAGE_SCN_MEM_EXECUTE es linealmente DEPENDIENTE de la clase. p-value: 2.54e-03
# La variable rdata_Characteristics_IMAGE_SCN_MEM_LOCKED es linealmente INDEPENDIENTE de la clase. p-value: 7.51e-01
# La variable rdata_Characteristics_IMAGE_SCN_MEM_NOT_PAGED es linealmente DEPENDIENTE de la clase. p-value: 1.79e-12
# La variable rdata_Characteristics_IMAGE_SCN_MEM_PRELOAD es linealmente INDEPENDIENTE de la clase. p-value: 7.51e-01
# La variable rdata_Characteristics_IMAGE_SCN_MEM_PURGEABLE es linealmente INDEPENDIENTE de la clase. p-value: 9.64e-02
# La variable rdata_Characteristics_IMAGE_SCN_MEM_READ es linealmente DEPENDIENTE de la clase. p-value: 0.00e+00
# La variable rdata_Characteristics_IMAGE_SCN_MEM_SHARED es linealmente DEPENDIENTE de la clase. p-value: 5.27e-19
# La variable rdata_Characteristics_IMAGE_SCN_MEM_WRITE es linealmente DEPENDIENTE de la clase. p-value: 2.23e-02
# La variable rdata_Characteristics_IMAGE_SCN_NO_DEFER_SPEC_EXC es linealmente DEPENDIENTE de la clase. p-value: 1.86e-12
# La variable rdata_Characteristics_IMAGE_SCN_TYPE_COPY es linealmente DEPENDIENTE de la clase. p-value: 7.86e-07
# La variable rdata_Characteristics_IMAGE_SCN_TYPE_DSECT es linealmente DEPENDIENTE de la clase. p-value: 1.65e-08
# La variable rdata_Characteristics_IMAGE_SCN_TYPE_GROUP es linealmente INDEPENDIENTE de la clase. p-value: 8.34e-02
# La variable rdata_Characteristics_IMAGE_SCN_TYPE_NOLOAD es linealmente DEPENDIENTE de la clase. p-value: 2.82e-05
# La variable rdata_Characteristics_IMAGE_SCN_TYPE_NO_PAD es linealmente DEPENDIENTE de la clase. p-value: 2.82e-05
# La variable rdata_Characteristics_IMAGE_SCN_TYPE_OVER es linealmente DEPENDIENTE de la clase. p-value: 1.69e-05

# %% [markdown]
# ## Variables a eliminar

# %% [markdown]
# Ejemplos independientes (pueden descartarse si quieres reducir dimensionalidad):
#
# SizeOfCode (p-value 0.15)
#
# SizeOfInitializedData (p-value 0.42)
#
# BaseOfCode, BaseOfData, ImageBase (~0.18)
#
# text_Characteristics_IMAGE_SCN_ALIGN_128BYTES (0.21)
#
# rdata_Characteristics_IMAGE_SCN_ALIGN_128BYTES (0.05 aprox)
#
# rdata_Characteristics_IMAGE_SCN_MEM_LOCKED (0.75)
#
# rdata_Characteristics_IMAGE_SCN_MEM_PRELOAD (0.75)
#
# rdata_Characteristics_IMAGE_SCN_MEM_PURGEABLE (0.096)
#
# rdata_Characteristics_IMAGE_SCN_TYPE_GROUP (0.083)
# ##333
# 92   text_Characteristics_IMAGE_SCN_CNT_UNINITIALIZ...  0.000000
# 149        rdata_Characteristics_IMAGE_SCN_TYPE_NO_PAD  0.000000
# 148        rdata_Characteristics_IMAGE_SCN_TYPE_NOLOAD  0.000000
# 147         rdata_Characteristics_IMAGE_SCN_TYPE_GROUP  0.000000
# 7                                        init_ss_value  0.000000
# 104          text_Characteristics_IMAGE_SCN_MEM_SHARED  0.000000
# 144  rdata_Characteristics_IMAGE_SCN_NO_DEFER_SPEC_EXC  0.000000
# 143          rdata_Characteristics_IMAGE_SCN_MEM_WRITE  0.000000
# 106   text_Characteristics_IMAGE_SCN_NO_DEFER_SPEC_EXC  0.000000
# 139        rdata_Characteristics_IMAGE_SCN_MEM_PRELOAD  0.000000
# 81         text_Characteristics_IMAGE_SCN_ALIGN_2BYTES  0.000000
# 110         text_Characteristics_IMAGE_SCN_TYPE_NO_PAD  0.000000
# 134          rdata_Characteristics_IMAGE_SCN_LNK_OTHER  0.000000
# 28                                         LoaderFlags  0.000000
# 99           text_Characteristics_IMAGE_SCN_MEM_LOCKED  0.000000
# 114     rdata_Characteristics_IMAGE_SCN_ALIGN_128BYTES  0.000000
# 130  rdata_Characteristics_IMAGE_SCN_CNT_UNINITIALI...  0.000000
# 63   DllCharacteristics_IMAGE_DLLCHARACTERISTICS_FO...  0.000000
# 95             text_Characteristics_IMAGE_SCN_LNK_INFO  0.000000
# 71       DllCharacteristics_IMAGE_LIBRARY_PROCESS_INIT  0.000000
# 101         text_Characteristics_IMAGE_SCN_MEM_PRELOAD  0.000000
# 73        DllCharacteristics_IMAGE_LIBRARY_THREAD_INIT  0.000000
# 94           text_Characteristics_IMAGE_SCN_LNK_COMDAT  0.000000
# 93                text_Characteristics_IMAGE_SCN_GPREL  0.000000
# 136        rdata_Characteristics_IMAGE_SCN_MEM_EXECUTE  0.000000

# %% [markdown]
# ### Mutual Information
# Mientras más alto el MI_score, más información aporta la variable para predecir la clase.

# %%
from sklearn.feature_selection import mutual_info_classif
import pandas as pd

# === 1. Calcular Mutual Information ===
mi_scores = mutual_info_classif(X, y, random_state=42)

# === 2. Crear DataFrame con resultados ===
df_mi = pd.DataFrame({
    "Feature": X.columns,
    "MI_score": mi_scores
}).sort_values(by="MI_score", ascending=False)

# === 3. Mostrar TODAS las filas en consola ===
pd.set_option("display.max_rows", None)
print(df_mi)

# %%
import matplotlib.pyplot as plt

# === Gráfico de barras con todas las características ===
plt.figure(figsize=(12, 40))  # alto grande para que entren todas
plt.barh(df_mi["Feature"], df_mi["MI_score"], color="skyblue")
plt.xlabel("Mutual Information Score")
plt.ylabel("Features")
plt.title("Importancia de características según Mutual Information")
plt.gca().invert_yaxis()  # para que las más altas queden arriba
plt.show()

# %% [markdown]
# ### Chi-Cuadradotest
# Chi-cuadrado (χ²) se usa principalmente cuando las variables son categóricas o discretas (incluyendo binarias como 0/1)

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import chi2

# === 1. Detectar variables binarias (solo 0 y 1) ===
binarias = [col for col in X.columns if set(X[col].dropna().unique()).issubset({0, 1})]

# Crear nuevo DataFrame solo con variables categóricas/binarias
X_bin = X[binarias].copy().astype(int)

print(f"Variables seleccionadas para Chi²: {binarias}")

# === 2. Calcular Chi² ===
chi_scores, p_values = chi2(X_bin, y)

# === 3. DataFrame con resultados + interpretación ===
chi2_results = pd.DataFrame({
    "Feature": X_bin.columns,
    "Chi2_score": chi_scores,
    "p_value": p_values,
    "Relacion_con_clase": [
        "DEPENDIENTE (p < 0.05)" if p < 0.05 else "INDEPENDIENTE (p >= 0.05)"
        for p in p_values
    ]
}).sort_values(by="Chi2_score", ascending=False)

# === 4. Mostrar tabla ===
print("\n=== Resultados Chi² (solo variables categóricas/binarias) ===")
print(chi2_results)

# === 5. Mostrar mensajes detallados por variable ===
print("\n=== Interpretación variable por variable ===")
for feature, chi, p in zip(X_bin.columns, chi_scores, p_values):
    if p < 0.05:
        print(f"La variable '{feature}' es DEPENDIENTE de la clase (p={p:.4e}, Chi²={chi:.2f})")
    else:
        print(f"La variable '{feature}' es INDEPENDIENTE de la clase (p={p:.4e}, Chi²={chi:.2f})")

# %% [markdown]
# ### Eliminacion de variables parte 2

# %%
# Lista de variables a eliminar según Pearson, F-test, Chi²
vars_a_eliminar = [
    "LoaderFlags",
    "BaseOfCode",
    "BaseOfData",
    "ImageBase",
    "AddressOfEntryPoint",
   "text_Characteristics_IMAGE_SCN_ALIGN_128BYTES",
    "rdata_Characteristics_IMAGE_SCN_ALIGN_128BYTES",
    "rdata_Characteristics_IMAGE_SCN_MEM_LOCKED",
    "rdata_Characteristics_IMAGE_SCN_MEM_PRELOAD",
    "rdata_Characteristics_IMAGE_SCN_MEM_PURGEABLE",
    "rdata_Characteristics_IMAGE_SCN_TYPE_GROUP",
    "text_Characteristics_IMAGE_SCN_MEM_PRELOAD",
    "text_Characteristics_IMAGE_SCN_MEM_PURGEABLE",
    "text_Characteristics_IMAGE_SCN_MEM_SHARED",
    "rdata_Characteristics_IMAGE_SCN_LNK_OTHER"
]
# Crear nuevo dataset filtrado
X_limpio = X.drop(columns=vars_a_eliminar, errors="ignore")

print(f"Dataset original: {X.shape[1]} variables")
print(f"Variables eliminadas: {len(vars_a_eliminar)}")
print(f"Dataset final: {X_limpio.shape[1]} variables")

# %% [markdown]
# ### Balanceo de clases

# %%
# Contar las clases
class_counts = y.value_counts()

# Gráfico de barras
plt.figure(figsize=(8,6))
class_counts.plot(kind='bar', color='red', edgecolor='black')

plt.title("Distribución de Clases en el Dataset")
plt.xlabel("Clase")
plt.ylabel("Número de muestras")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Conversion a label encoder de la variable objetivo

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_enc = le.fit_transform(y)

print(le.classes_)  
# ['Benign' 'Ransomware' 'Trojan']

# %%
print(y.head(10))     # originales
print(y_enc[:10])     # convertidos

# %% [markdown]
# ### Dividir el conjunto de train/test

# %%
X_train, X_test, y_train, y_test = train_test_split(
X_limpio, y_enc, test_size = 0.20, random_state=42, stratify=y_enc)

# %%
# Si quieres solo tamaños:
print("\nTamaños de los conjuntos:")
print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)

# %% [markdown]
# ### Aplicar sobremuestreo (Oversampling) Tecnica SMOTE

# %%
# === 3. Aplicar SMOTE SOLO en train ===
smote = SMOTE(random_state=42)
X_train_bal, y_train_bal = smote.fit_resample(X_train, y_train)

print("Distribución original en train:", Counter(y_train))
print("Distribución balanceada en train:", Counter(y_train_bal))
print("Distribución en test (sin tocar):", Counter(y_test))

# %% [markdown]
# ### Grafico despues de aplicar la tecnica de Smote

# %%
from collections import Counter
import matplotlib.pyplot as plt

# Contar clases después de SMOTE
class_counts = Counter(y_train_bal)

# Gráfico
plt.bar(class_counts.keys(), class_counts.values(), color="orange")
plt.title("Distribución de clases después de SMOTE (Train)")
plt.xlabel("Clases")
plt.ylabel("Número de muestras")

# Mostrar valores encima de cada barra
for clase, count in class_counts.items():
    plt.text(clase, count + 50, str(count), ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.show()

# %% [markdown]
# ### Entrenamiento del modelo con GradientBossting

# %%
from sklearn.ensemble import GradientBoostingClassifier


# Definir modelo
model = GradientBoostingClassifier(
    n_estimators=50,      # número de árboles
    learning_rate=0.1,    # qué tanto aprende cada árbol
    max_depth=3,          # profundidad máxima de cada árbol
    random_state=42
)

model.fit(X_train_bal, y_train_bal)  # Ajusta el modelo a los datos de entrenamiento

# %% [markdown]
# ### Evaluar el modelo

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nEvaluacion del modelo:\n", classification_report(y_test, y_pred, target_names=le.classes_))

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, X, y_enc, cv=5, scoring="accuracy")
print("Accuracy promedio CV:", scores.mean())

# %% [markdown]
# ### Metricas de evaluacion

# %% [markdown]
# ### Matriz de confusion

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=le.classes_)
disp.plot(cmap="Blues")

# %% [markdown]
# ### Curva Roc

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Binarizamos las etiquetas reales (One-vs-Rest)
y_test_bin = label_binarize(y_test, classes=[0,1,2])  # 3 clases
y_pred_prob = model.predict_proba(X_test)  # probabilidades en lugar de clases

# Calcular ROC y AUC para cada clase
fpr = {}
tpr = {}
roc_auc = {}
for i in range(3):  # para cada clase
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Graficar curvas ROC
plt.figure(figsize=(8,6))
for i, clase in enumerate(le.classes_):
    plt.plot(fpr[i], tpr[i], label=f"{clase} (AUC = {roc_auc[i]:.2f})")

# Línea diagonal (modelo aleatorio)
plt.plot([0,1],[0,1],'k--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Curva ROC por clase")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Valor AUC

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_auc_score

# Binarizar y calcular probabilidades
y_test_bin = label_binarize(y_test, classes=[0,1,2])
y_pred_prob = model.predict_proba(X_test)

# Calcular AUC promedio
auc_macro = roc_auc_score(y_test_bin, y_pred_prob, average="macro")
auc_weighted = roc_auc_score(y_test_bin, y_pred_prob, average="weighted")

print("AUC Macro promedio:", auc_macro)
print("AUC Ponderado:", auc_weighted)

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(model, X, y_enc, cv=5, scoring="accuracy")
print("Accuracies CV:", scores)
print("Promedio:", scores.mean())

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score
for i, clase in enumerate(le.classes_):
    precision, recall, _ = precision_recall_curve(y_test_bin[:, i], y_pred_prob[:, i])
    ap = average_precision_score(y_test_bin[:, i], y_pred_prob[:, i])
    plt.plot(recall, precision, label=f"{clase} (AP = {ap:.2f})")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Curva Precision-Recall")
plt.legend()
plt.show()
